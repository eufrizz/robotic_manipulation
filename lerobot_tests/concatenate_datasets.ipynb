# %%
# from lerobot.datasets.lerobot_datasets import , LerobotDataset
from lerobot.datasets.lerobot_dataset import LeRobotDataset, LeRobotDataset
from lerobot.datasets.factory import make_dataset, make_dataset
from lerobot.datasets.dataset_tools import merge_datasets

# %%
dataset_paths = ["datasets/lite6_record_scripted_251104_rand_colour", "datasets/lite6_record_scripted_251027_close_init"]
datasets = []
for ds in dataset_paths:
    # ds_meta = LeRobotDatasetMetadata(
    #         ds, root="."
    #     )
        # dataset = LeRobotDataset(
        #     cfg.dataset.repo_id,
        #     root=cfg.dataset.root,
        #     episodes=cfg.dataset.episodes,
        #     delta_timestamps=delta_timestamps,
        #     image_transforms=image_transforms,
        #     revision=cfg.dataset.revision,
        #     video_backend=cfg.dataset.video_backend,
        # )
    datasets.append(
        LeRobotDataset(
        repo_id=ds,
        root=ds,
        episodes=range(50)
        )
    )
datasets

# %%
dataset = merge_datasets(
    datasets,
    output_repo_id="lite6_record_scripted_251104_rand_col+close",
    output_dir="datasets/lite6_record_scripted_251104_rand_col+close",
)
